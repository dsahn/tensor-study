# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
tf.compat.v1.disable_resource_variables()
import numpy as np

data = np.loadtxt('./data.csv', delimiter=',', unpack=True, dtype='float32')

x_data = np.transpose(data[0:2])
y_data = np.transpose(data[2:])

# 학습회수를 카운팅하는 변수
global_step = tf.Variable(0, trainable=False, name='global_step')

X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)

W1 = tf.Variable(tf.random_uniform([2,10], -1., 1.))
L1 = tf.nn.relu(tf.matmul(X, W1))

W2 = tf.Variable(tf.random_uniform([10,20], -1., 1.))
L2 = tf.nn.relu(tf.matmul(L1, W2))

W3 = tf.Variable(tf.random_uniform([20,3], -1., 1.))
model = tf.matmul(L2, W3)

cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=Y, logits=model))

optimizer = tf.train.AdamOptimizer(learning_rate=0.01)
train_op = optimizer.minimize(cost, global_step=global_step)

sess = tf.Session()
# tf.global_variables : 앞서 정의한 변수들을 가져오는 변수
saver = tf.train.Saver(tf.global_variables())

ckpt = tf.train.get_checkpoint_state('./model')
if ckpt and tf.train.checkpoint_exists(ckpt.model_checkpoint_path):
    # 학습모델이 이미 있다면 사용된 학습값 재사용
    saver.restore(sess, ckpt.model_checkpoint_path)
else:
    # 학습모델이 없으면 초기화
    sess.run(tf.global_variables_initializer())

for step in range(2):
    sess.run(train_op, feed_dict={X: x_data, Y: y_data})
    
    print('Step: %d, ' % sess.run(global_step),
         'Cost: %.3f ' % sess.run(cost, feed_dict={X:x_data, Y:y_data}))

# 학습된 변수들 저장
saver.save(sess, './model/dnn.ckpt', global_step=global_step)

prediction = tf.argmax(model, 1)
target = tf.argmax(Y, 1)
print('pred: ', sess.run(prediction, feed_dict={X: x_data}))
print('real: ', sess.run(target, feed_dict={Y: y_data}))

is_correct = tf.equal(prediction, target)
accuracy = tf.reduce_mean(tf.cast(is_correct, tf.float32))
print('accuracy: %.2f' % sess.run(accuracy * 100, feed_dict={X: x_data, Y:y_data}))
# Out:
# INFO:tensorflow:Restoring parameters from ./model/dnn.ckpt-2
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#
# ~/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#
# ~/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#
# NotFoundError: Key Variable_12 not found in checkpoint
# 	 [[{{node save_4/RestoreV2}}]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# ~/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1298         sess.run(self.saver_def.restore_op_name,
# -> 1299                  {self.saver_def.filename_tensor_name: save_path})
#    1300     except errors.NotFoundError as err:
#
# ~/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     957       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 958                          run_metadata_ptr)
#     959       if run_metadata:
#
# ~/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1180       results = self._do_run(handle, final_targets, final_fetches,
# -> 1181                              feed_dict_tensor, options, run_metadata)
#    1182     else:
#
# ~/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#
# ~/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1383                     'disable_meta_optimizer = True')
# -> 1384       raise type(e)(node_def, op, message)
#    1385
#
# NotFoundError: Key Variable_12 not found in checkpoint
# 	 [[node save_4/RestoreV2 (defined at <ipython-input-6-3a998d67b240>:33) ]]
#
# Original stack trace for 'save_4/RestoreV2':
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tornado/ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tornado/gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tornado/gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 538, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2895, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3166, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-3a998d67b240>", line 33, in <module>
#     saver = tf.train.Saver(tf.global_variables())
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/training/saver.py", line 836, in __init__
#     self.build()
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/training/saver.py", line 848, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/training/saver.py", line 886, in _build
#     build_restore=build_restore)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/training/saver.py", line 516, in _build_internal
#     restore_sequentially, reshape)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/training/saver.py", line 336, in _AddRestoreOps
#     restore_sequentially)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/training/saver.py", line 583, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/ops/gen_io_ops.py", line 1506, in restore_v2
#     name=name)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py", line 744, in _apply_op_helper
#     attrs=attr_protos, op_def=op_def)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/framework/ops.py", line 3327, in _create_op_internal
#     op_def=op_def)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/framework/ops.py", line 1791, in __init__
#     self._traceback = tf_stack.extract_stack()
#
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# ~/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/training/py_checkpoint_reader.py in get_tensor(self, tensor_str)
#      69     return CheckpointReader.CheckpointReader_GetTensor(
# ---> 70         self, compat.as_bytes(tensor_str))
#      71   # TODO(b/143319754): Remove the RuntimeError casting logic once we resolve the
#
# RuntimeError: Key _CHECKPOINTABLE_OBJECT_GRAPH not found in checkpoint
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# ~/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1308       try:
# -> 1309         names_to_keys = object_graph_key_mapping(save_path)
#    1310       except errors.NotFoundError:
#
# ~/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/training/saver.py in object_graph_key_mapping(checkpoint_path)
#    1626   reader = py_checkpoint_reader.NewCheckpointReader(checkpoint_path)
# -> 1627   object_graph_string = reader.get_tensor(trackable.OBJECT_GRAPH_PROTO_KEY)
#    1628   object_graph_proto = (trackable_object_graph_pb2.TrackableObjectGraph())
#
# ~/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/training/py_checkpoint_reader.py in get_tensor(self, tensor_str)
#      73   except RuntimeError as e:
# ---> 74     error_translator(e)
#      75
#
# ~/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/training/py_checkpoint_reader.py in error_translator(e)
#      34       'matching files for') in error_message:
# ---> 35     raise errors_impl.NotFoundError(None, None, error_message)
#      36   elif 'Sliced checkpoints are not supported' in error_message or (
#
# NotFoundError: Key _CHECKPOINTABLE_OBJECT_GRAPH not found in checkpoint
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-6-3a998d67b240> in <module>
#      36 if ckpt and tf.train.checkpoint_exists(ckpt.model_checkpoint_path):
#      37     # 학습모델이 이미 있다면 사용된 학습값 재사용
# ---> 38     saver.restore(sess, ckpt.model_checkpoint_path)
#      39 else:
#      40     # 학습모델이 없으면 초기화
#
# ~/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1313         # a helpful message (b/110263146)
#    1314         raise _wrap_restore_error_with_msg(
# -> 1315             err, "a Variable name or other graph key that is missing")
#    1316
#    1317       # This is an object-based checkpoint. We'll print a warning and then do
#
# NotFoundError: Restoring from checkpoint failed. This is most likely due to a Variable name or other graph key that is missing from the checkpoint. Please ensure that you have not altered the graph expected based on the checkpoint. Original error:
#
# Key Variable_12 not found in checkpoint
# 	 [[node save_4/RestoreV2 (defined at <ipython-input-6-3a998d67b240>:33) ]]
#
# Original stack trace for 'save_4/RestoreV2':
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tornado/ioloop.py", line 688, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tornado/gen.py", line 814, in inner
#     self.ctx_run(self.run)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tornado/gen.py", line 775, in run
#     yielded = self.gen.send(value)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 358, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 261, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 538, in execute_request
#     user_expressions, allow_stdin,
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#     yielded = ctx_run(next, result)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 302, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 539, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2895, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2940, in _run_cell
#     return runner(coro)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3166, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-3a998d67b240>", line 33, in <module>
#     saver = tf.train.Saver(tf.global_variables())
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/training/saver.py", line 836, in __init__
#     self.build()
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/training/saver.py", line 848, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/training/saver.py", line 886, in _build
#     build_restore=build_restore)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/training/saver.py", line 516, in _build_internal
#     restore_sequentially, reshape)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/training/saver.py", line 336, in _AddRestoreOps
#     restore_sequentially)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/training/saver.py", line 583, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/ops/gen_io_ops.py", line 1506, in restore_v2
#     name=name)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py", line 744, in _apply_op_helper
#     attrs=attr_protos, op_def=op_def)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/framework/ops.py", line 3327, in _create_op_internal
#     op_def=op_def)
#   File "/home/dev/workspace/conf/conda-env/lib/python3.7/site-packages/tensorflow/python/framework/ops.py", line 1791, in __init__
#     self._traceback = tf_stack.extract_stack()
